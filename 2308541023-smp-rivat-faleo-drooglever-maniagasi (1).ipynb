# %%
## import math

# Definisikan persamaan x^2 + x - 1 = 0
def persamaan(x):
    return x**2 + x - 1

# Cari akar dari persamaan menggunakan rumus kuadrat
a, b, c = 1, 1, -1
x = (-b + math.sqrt(b**2 - 4*a*c)) / (2*a)

x = float(input("nilai x adalah"))
x_1 = 10
x_2 = -12

# Hitung nilai n
n = 2026 / 3

#masukkan nilai x antara x 1 = 10 atau x 2 = -12
if x>0:
    print("Nilai n adalah {}".format(positif(x)))
else:
    print("Nilai n adalah {}".format(negatif(x)))
# Out:
# nilai x adalah -12
# Nilai n adalah 675.3333333333334

# %%
math.log(100,16)
# Out:
# 1.6609640474436813

# %%
math.log(100,12)
# Out:
# 1.8532568160582539
